# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
# Load Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=60)

# %%
# Train SVM classifier
clf = SVC(kernel='linear')
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Predict on the test set
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)

# %%
# Print the classification report
print(classification_report(y_test, y_pred_test, target_names=iris.target_names))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        24
#   versicolor       0.88      0.94      0.91        16
#    virginica       0.95      0.90      0.92        20
#
#     accuracy                           0.95        60
#    macro avg       0.94      0.95      0.94        60
# weighted avg       0.95      0.95      0.95        60

# %%
# Calculate accuracy
accuracy_train = accuracy_score(y_train, y_pred_train)
accuracy_test = accuracy_score(y_test, y_pred_test)

# Print the accuracies
print('Accuracy of SVM Train: ', accuracy_train)
print('Accuracy of SVM Test: ', accuracy_test)

# Display the number of mislabeled points
print("Number of mislabeled points out of a total %d points: %d" % (X_test.shape[0], (y_test != y_pred_test).sum()))
# Out:
# Accuracy of SVM Train:  0.9777777777777777
# Accuracy of SVM Test:  0.95
# Number of mislabeled points out of a total 60 points: 3
